# %% [markdown]
# <a href="https://colab.research.google.com/github/mwangidyce/AIAlgorithmsProject/blob/master/Recsys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import drive
# drive.mount("/content/drive")
# !unzip recsys_data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/Resume_Files/RigElectrician_3189
#   inflating: data/Resume_Files/PravinSehgal_23912
#   inflating: data/Resume_Files/GretellSanchez_22499
#   inflating: data/Resume_Files/SmallBusinessAccountExecutive_10920
#   inflating: data/Resume_Files/AccountManager_15586
#   inflating: data/Resume_Files/AshliBorgman_46758
#   inflating: data/Resume_Files/BusDriver_153
#   inflating: data/Resume_Files/HayesPurcell_22678
#   inflating: data/Resume_Files/JasmineWilliams_20473
#   inflating: data/Resume_Files/MaryBrennan_43799
#   inflating: data/Resume_Files/LilyNicoleFlores_7310
#   inflating: data/Resume_Files/ColleenGill_44044
#   inflating: data/Resume_Files/heavyequipmentoperator_16414
#   inflating: data/Resume_Files/Landscaper_16639
#   inflating: data/Resume_Files/NursePractitioner_19996
#   inflating: data/Resume_Files/AnaGoodwin_37580
#   inflating: data/Resume_Files/DebbyAnex_26282
#   inflating: data/Resume_Files/ProgrammerComputerTechnician_3286
#   inflating: data/Resume_Files/JobSeeker_34997
#   inflating: data/Resume_Files/MelissaLafata_30285
#   inflating: data/Resume_Files/JonathanGee_23567
#   inflating: data/Resume_Files/ArmenAghekyan_30348
#   inflating: data/Resume_Files/ChargeNurse_213
#   inflating: data/Resume_Files/CUSTOMERSERVICEREP_16033
#   inflating: data/Resume_Files/DanielleHruska_12334
#   inflating: data/Resume_Files/BereavementCoordinator_16901
#   inflating: data/Resume_Files/Operator_16551
#   inflating: data/Resume_Files/RebeccaCurrie_7641
#   inflating: data/Resume_Files/Bartender_9626
#   inflating: data/Resume_Files/Riceplant_3606
#   inflating: data/Resume_Files/Softlineslead_24542
#   inflating: data/Resume_Files/PatientRegistrationClerk_22215
#   inflating: data/Resume_Files/ShanequaKnox_39030
#   inflating: data/Resume_Files/JeaneneMelvin_30375
#   inflating: data/Resume_Files/KellyFinucan_45481
#   inflating: data/Resume_Files/CustomerServiceRep_35526
#   inflating: data/Resume_Files/ProjectAssistantTechnicalWriter_20055
#   inflating: data/Resume_Files/MortgageCreditAnalyst_9476
#   inflating: data/Resume_Files/Detailer_4205
#   inflating: data/Resume_Files/AnnaVasquez_1148
#   inflating: data/Resume_Files/BenFennen_41362
#   inflating: data/Resume_Files/CNCMachineOperatorplaquefabricator_48081
#   inflating: data/Resume_Files/BritneyPerry_4797
#   inflating: data/Resume_Files/SophiaConti_13744
#   inflating: data/Resume_Files/AdministratorAssistant_48354
#   inflating: data/Resume_Files/MedicalAssistant_43505
#   inflating: data/Resume_Files/MaxinePersky_46854
#   inflating: data/Resume_Files/LeadForeman_44363
#   inflating: data/Resume_Files/LeaRector_46817
#   inflating: data/Resume_Files/MikePelayo_32402
#   inflating: data/Resume_Files/SamirKulkarni_42034
#   inflating: data/Resume_Files/JonathanHenry_38688
#   inflating: data/Resume_Files/ClericalAssistant_35586
#   inflating: data/Resume_Files/DerrickBarr_45725
#   inflating: data/Resume_Files/JacquelineFontanez_13322
#   inflating: data/Resume_Files/PeteMelrose_30475
#   inflating: data/Resume_Files/BartenderWaitress_10244
#   inflating: data/Resume_Files/KellyCalvin_23358
#   inflating: data/Resume_Files/SeniorResearchAssistant_6075
#   inflating: data/Resume_Files/KeandraRomeo_21941
#   inflating: data/Resume_Files/CortezMaronie_39901
#   inflating: data/Resume_Files/NataliaStoos_36873
#   inflating: data/Resume_Files/MatthewVolz_14323
#   inflating: data/Resume_Files/VanessaPerez_18825
#   inflating: data/Resume_Files/TeamMember_33330
#   inflating: data/Resume_Files/JonSchofield_12280
#   inflating: data/Resume_Files/JamesBlack_31016
#   inflating: data/Resume_Files/RobertMcDonald_4319
#   inflating: data/Resume_Files/BrittanyONeal_48827
#   inflating: data/Resume_Files/Janitorial_35174
#   inflating: data/Resume_Files/MarvinChan_24024
#   inflating: data/Resume_Files/QC_3420
#   inflating: data/Resume_Files/CribAttendant_34487
#   inflating: data/Resume_Files/RegisteredMedicalAssistant_12014
#   inflating: data/Resume_Files/TravelingMusician_2010
#   inflating: data/Resume_Files/SkyBennett_27291
#   inflating: data/Resume_Files/KathleenOConnor_40443
#   inflating: data/Resume_Files/Receptionist_36280
#   inflating: data/Resume_Files/NicholasWheeler_25648
#   inflating: data/Resume_Files/ChristopherBush_43724
#   inflating: data/Resume_Files/StanleyJackson_22728
#   inflating: data/Resume_Files/PersonalizedLivingDirector_2750
#   inflating: data/Resume_Files/VALERIEBRAY_17939
#   inflating: data/Resume_Files/DeztiniPhillips_46679
#   inflating: data/Resume_Files/ShawnWhite_12976
#   inflating: data/Resume_Files/ReginaCamacho_18799
#   inflating: data/Resume_Files/packinglabel_27606
#   inflating: data/Resume_Files/JustinRogers_940
#   inflating: data/Resume_Files/Volunteer_10227
#   inflating: data/Resume_Files/ReceiverOrderPuller_36689
#   inflating: data/Resume_Files/SeniorDistrictCoolingEngineer_2554
#   inflating: data/Resume_Files/MiddlewareAdministrator_380
#   inflating: data/Resume_Files/SalesandCustomerServiceRepresentative_34656
#   inflating: data/Resume_Files/JessicaTurnerSchaefer_7096
#   inflating: data/Resume_Files/SalesandMarketingRepresentative_44585
#   inflating: data/Resume_Files/DavidAdams_38938
#   inflating: data/Resume_Files/JennyBotor_25524
#   inflating: data/Resume_Files/MichaelHowell_26706
#   inflating: data/Resume_Files/EngineeringAide_35408
#   inflating: data/Resume_Files/HeavyMachineryOperator_3297
#   inflating: data/Resume_Files/TaylorWilliams_20874
#   inflating: data/Resume_Files/PersonalCareAssistantPCA_5519
#   inflating: data/Resume_Files/AaronHamilton_7688
#   inflating: data/Resume_Files/JobSeeker_25468
#   inflating: data/Resume_Files/BrennaMarnell_13683
#   inflating: data/Resume_Files/PatriciaODonnell_44138
#   inflating: data/Resume_Files/JobSeeker_40743
#   inflating: data/Resume_Files/PatrickBusby_46682
#   inflating: data/Resume_Files/AssemblerIII_14728
#   inflating: data/Resume_Files/CustomerServiceRepresentative_39326
#   inflating: data/Resume_Files/ClientLiaison_29571
#   inflating: data/Resume_Files/TerrancePittman_47184
#   inflating: data/Resume_Files/GabrielaBarriga_30549
#   inflating: data/Resume_Files/YuliaYashchenko_12874
#   inflating: data/Resume_Files/ShiftSupervisor_34213
#   inflating: data/Resume_Files/KelleyTerrence_31899
#   inflating: data/Resume_Files/JobSeeker_41131
#   inflating: data/Resume_Files/JobSeeker_47296
#   inflating: data/Resume_Files/RakieyaSkinner_27141
#   inflating: data/Resume_Files/MartinThompson_5169
#   inflating: data/Resume_Files/Hairdresser_43554
#   inflating: data/Resume_Files/DuaneBaugher_2703
#   inflating: data/Resume_Files/YueLi_13499
#   inflating: data/Resume_Files/Recaid_10991
#   inflating: data/Resume_Files/KindergartenClassroomVolunteer_41161
#   inflating: data/Resume_Files/NitrogenPumpOperator_17137
#   inflating: data/Resume_Files/JobSeeker_47480
#   inflating: data/Resume_Files/WHassan_40307
#   inflating: data/Resume_Files/DickSmith_9362
#   inflating: data/Resume_Files/Picker_11121
#   inflating: data/Resume_Files/RonaldStranski_23535
#   inflating: data/Resume_Files/JobSeeker_5899
#   inflating: data/Resume_Files/MorganHiggins_38996
#   inflating: data/Resume_Files/CarpetCleaningTechnician_6069
#   inflating: data/Resume_Files/BehaviorTech_29771
#   inflating: data/Resume_Files/RockellTracy_37905
#   inflating: data/Resume_Files/CharlesScarbrough_20617
#   inflating: data/Resume_Files/SherryJames_23128
#   inflating: data/Resume_Files/JobSeeker_9683
#   inflating: data/Resume_Files/CertifiedNursingAssistant_43161
#   inflating: data/Resume_Files/KimBaity_20458
#   inflating: data/Resume_Files/SeniorAuditSpecialist_35495
#   inflating: data/Resume_Files/BrandonPergerson_22606
#   inflating: data/Resume_Files/TeacherTutor_34822
#   inflating: data/Resume_Files/SunnyDesai_4891
#   inflating: data/Resume_Files/Robertaolguin_23440
#   inflating: data/Resume_Files/MichaelTonkonogy_30489
#   inflating: data/Resume_Files/FreightAssociate_3232
#   inflating: data/Resume_Files/WiltonBurton_17759
#   inflating: data/Resume_Files/jessicamalloy_12268
#   inflating: data/Resume_Files/EventStaffMember_5766
#   inflating: data/Resume_Files/FoodHandlerCashier_14772
#   inflating: data/Resume_Files/MarcusChester_4705
#   inflating: data/Resume_Files/ForkliftOperator_34782
#   inflating: data/Resume_Files/Cashier_6077
#   inflating: data/Resume_Files/DataEntry_10124
#   inflating: data/Resume_Files/Davidposey_26533
#   inflating: data/Resume_Files/Tankerman_34926
#   inflating: data/Resume_Files/InterventionCounselorvolunteer_9742
#   inflating: data/Resume_Files/AthleticDepartmentGraduateAssistantandSwimandDiveCoach_351
#   inflating: data/Resume_Files/SrETLTESTER_12581
#   inflating: data/Resume_Files/MitchellHalcomb_26429
#   inflating: data/Resume_Files/ColtBundy_5224
#   inflating: data/Resume_Files/CentralServiceTechnicianSterileProcessingTechnician_35175
#   inflating: data/Resume_Files/SandraReyes_38473
#   inflating: data/Resume_Files/ExecutiveAssistant_14800
#   inflating: data/Resume_Files/tempworker_36528
#   inflating: data/Resume_Files/Eauclaireacademy_35569
#   inflating: data/Resume_Files/ASSTMANEGER_42784
#   inflating: data/Resume_Files/MaintinanceUtility_10747
#   inflating: data/Resume_Files/JessicaLQuery_39074
#   inflating: data/Resume_Files/AssistantManager_33731
#   inflating: data/Resume_Files/KristinaSlarve_7440
#   inflating: data/Resume_Files/WarehouseWorker_16422
#   inflating: data/Resume_Files/FelixBeltre_22705
#   inflating: data/Resume_Files/CoreyPitts_6594
#   inflating: data/Resume_Files/DanaLane_19266
#   inflating: data/Resume_Files/JobSeeker_28049
#   inflating: data/Resume_Files/92YSupplySpecialist_35286
#   inflating: data/Resume_Files/McDonaldsCrewMember_9237
#   inflating: data/Resume_Files/MachineOperator_40826
#   inflating: data/Resume_Files/PoliceOfficer_27853
#   inflating: data/Resume_Files/Associate_39646
#   inflating: data/Resume_Files/WebDeveloper_34322
#   inflating: data/Resume_Files/MatthewFranitti_6460
#   inflating: data/Resume_Files/JorgeDeLaNoval_42249
#   inflating: data/Resume_Files/AileenMatute_19070
#   inflating: data/Resume_Files/MirkeyaPierre_19477
#   inflating: data/Resume_Files/JosephineHolguin_46299
#   inflating: data/Resume_Files/JobSeeker_25340
#   inflating: data/Resume_Files/JobSeeker_10680
#   inflating: data/Resume_Files/Assistinfeeding_35819
#  extracting: data/Resume_Files/ContructionForman_16237
#   inflating: data/Resume_Files/MattWalls_12107
#   inflating: data/Resume_Files/FieldServiceTechnician_57
#   inflating: data/Resume_Files/ZechManyon_31546
#   inflating: data/Resume_Files/ZacharyBailey_8400
#   inflating: data/Resume_Files/KennethPolley_37470
#   inflating: data/Resume_Files/AkbarMaqbool_23376
#   inflating: data/Resume_Files/CassandraMackin_24377
#   inflating: data/Resume_Files/Teller_3450
#   inflating: data/Resume_Files/IanRueckert_10037
#   inflating: data/Resume_Files/EnvironmentalServicesAide_11059
#   inflating: data/Resume_Files/Opticalcontrolclerk_35670
#   inflating: data/Resume_Files/SalesAssociate_44865
#   inflating: data/Resume_Files/SWDoperator_29847
#   inflating: data/Resume_Files/TeriBloomer_42267
#   inflating: data/Resume_Files/Maintenancetech_28364
#   inflating: data/Resume_Files/Laborer_44864
#   inflating: data/Resume_Files/JorgeGalvez_38182
#   inflating: data/Resume_Files/ThomasJones_31388
#   inflating: data/Resume_Files/JasmineSimpson_21234
#   inflating: data/Resume_Files/NycoleHarris_20987
#   inflating: data/Resume_Files/HaroldYoumans_30297
#   inflating: data/Resume_Files/DianBush_21405
#   inflating: data/Resume_Files/LindseyWilliams_42211
#   inflating: data/Resume_Files/OpticianMembershipCoordinatorCakeDecorator_48104
#   inflating: data/Resume_Files/ResearchScientist_16516
#   inflating: data/Resume_Files/MichaelCarfagno_13199
#   inflating: data/Resume_Files/JustinDowden_12799
#   inflating: data/Resume_Files/AdrianPetersen_18876
#   inflating: data/Resume_Files/AshantiMcGrier_42339
#   inflating: data/Resume_Files/SeniorVicePresidentLoanReviewManager_25272
#   inflating: data/Resume_Files/DirectorofSalesOperations_9734
#   inflating: data/Resume_Files/Controller_34589
#   inflating: data/Resume_Files/KaliyahFaison_48996
#   inflating: data/Resume_Files/CharlesTucker_31277
#   inflating: data/Resume_Files/FramerLaborer_35513
#   inflating: data/Resume_Files/VanessaAguilar_41916
#   inflating: data/Resume_Files/ClaimsExaminerII_46476
#   inflating: data/Resume_Files/SoftwareAutomationTester_39242
#   inflating: data/Resume_Files/LandmanTitleAbstractor_10719
#   inflating: data/Resume_Files/Farmer_45083
#   inflating: data/Resume_Files/ProviderEnrollmentSpecialistLeadProviderEnrollmentSpecialistProviderEnrollmentSupervisor_28006
#   inflating: data/Resume_Files/ChardayDavis_20916
#   inflating: data/Resume_Files/SalesRepresentative_48187
#   inflating: data/Resume_Files/SupportTeamMemberElectedSecretary_34962
#   inflating: data/Resume_Files/AutoMechanic_45862
#   inflating: data/Resume_Files/MarquellWatkins_7834
#   inflating: data/Resume_Files/ApplicationEngineer_42588
#   inflating: data/Resume_Files/ChristianGonzalez_37492
#   inflating: data/Resume_Files/ExperiencedServer_39430
#   inflating: data/Resume_Files/SeniorContentTeamLead_48467
#   inflating: data/Resume_Files/NakishaButts_21361
#   inflating: data/Resume_Files/Goodwill_25336
#   inflating: data/Resume_Files/ShippingandReceiving_35874
#   inflating: data/Resume_Files/SandyBlankenship_38837
#   inflating: data/Resume_Files/AccountRepresentative_34935
#   inflating: data/Resume_Files/RN_572
#   inflating: data/Resume_Files/KevinMcKenna_20929
#   inflating: data/Resume_Files/DevinJones_10884
#   inflating: data/Resume_Files/DarrellPeters_24112
#   inflating: data/Resume_Files/JoyceZukerman_20364
#   inflating: data/Resume_Files/AnneHarris_12751
#   inflating: data/Resume_Files/RNadministrator_3025
#   inflating: data/Resume_Files/SurveyCrew_49095
#   inflating: data/Resume_Files/RyanParrish_1254
#   inflating: data/Resume_Files/FrieghtHandler_48651
#   inflating: data/Resume_Files/None_47306
#   inflating: data/Resume_Files/CertifiedTaxPreparer_27762
#   inflating: data/Resume_Files/Cashier_16678
#   inflating: data/Resume_Files/KathyFetherlin_750
#   inflating: data/Resume_Files/XiongVang_19542
#   inflating: data/Resume_Files/PatientCareCoordinator_35668
#   inflating: data/Resume_Files/TrenNarioMarshall_32111
#   inflating: data/Resume_Files/RehabOfficeAssistant_358
#   inflating: data/Resume_Files/Manager_10348
#   inflating: data/Resume_Files/ProduceAssociate_17478
#   inflating: data/Resume_Files/AndreaFuentes_1745
#   inflating: data/Resume_Files/LinseyNeptune_1457
#   inflating: data/Resume_Files/CookDishwasher_34089
#   inflating: data/Resume_Files/JasonOakley_20117
#   inflating: data/Resume_Files/NurseryAttendantTeacher_11502
#   inflating: data/Resume_Files/ContractHRRepresentative_34584
#  extracting: data/Resume_Files/Recruiter_33631
#   inflating: data/Resume_Files/erichmiller_21292
#   inflating: data/Resume_Files/DemetriaHead_21847
#   inflating: data/Resume_Files/SoftwareEngineer_4093
#   inflating: data/Resume_Files/Manager_39386
#   inflating: data/Resume_Files/Assistingclinical_295
#   inflating: data/Resume_Files/Lpn_5397
#   inflating: data/Resume_Files/HVACServiceTechnician_14769
#   inflating: data/Resume_Files/ExternSite_17461
#   inflating: data/Resume_Files/JeremyGrisham_22588
#   inflating: data/Resume_Files/BryantRichardson_43880
#   inflating: data/Resume_Files/AtinaFrame_21000
#   inflating: data/Resume_Files/PhillipSchultz_42104
#   inflating: data/Resume_Files/SoniaVelazquez_44357
#   inflating: data/Resume_Files/JonathanBarry_46908
#   inflating: data/Resume_Files/TiffanyGlover_7791
#  extracting: data/Resume_Files/Cook_40766
#   inflating: data/Resume_Files/AngelaStephens_25858
#   inflating: data/Resume_Files/survivalsturgis_31852
#   inflating: data/Resume_Files/Proctor_376
#   inflating: data/Resume_Files/ArnelReyes_6857
#   inflating: data/Resume_Files/AmrithaPrasanna_42202
#   inflating: data/Resume_Files/BernardARamirez_18430
#   inflating: data/Resume_Files/ServerShiftLeader_35907
#   inflating: data/Resume_Files/Internship_36269
#   inflating: data/Resume_Files/angelhowze_30161
#   inflating: data/Resume_Files/BeraPalleras_8185
#   inflating: data/Resume_Files/MaganPerez_25769
#   inflating: data/Resume_Files/coordinator_42946
#   inflating: data/Resume_Files/FreelanceFashionDesigner_11641
#   inflating: data/Resume_Files/Warehouseman_44462
#   inflating: data/Resume_Files/JessieLogan_12836
#   inflating: data/Resume_Files/GingerMansfield_37477
#   inflating: data/Resume_Files/RiccieGray_1084
#   inflating: data/Resume_Files/FleetDriver_35640
#   inflating: data/Resume_Files/JoseLira_6829
#   inflating: data/Resume_Files/Foremanpainter_49313
#   inflating: data/Resume_Files/PhantaDavis_22882
#   inflating: data/Resume_Files/JasonSack_38463
#   inflating: data/Resume_Files/EdwardBrown_38275
#   inflating: data/Resume_Files/RachelHouseholder_7061
#   inflating: data/Resume_Files/BrendaCruz_18851
#   inflating: data/Resume_Files/LuisPerez_13553
#   inflating: data/Resume_Files/MichaelJoyner_46349
#   inflating: data/Resume_Files/JamesThompson_27448
#   inflating: data/Resume_Files/GrantWriterCoordinator_10207
#   inflating: data/Resume_Files/JoshuaMcLaurin_43867
#   inflating: data/Resume_Files/SilviaGarciaCarvajal_19504
#   inflating: data/Resume_Files/OrderSelectorForkliftOperator_3969
#   inflating: data/Resume_Files/TerritoryManager_17292
#   inflating: data/Resume_Files/JobSeeker_49911
#   inflating: data/Resume_Files/ProduceAssociate_608
#   inflating: data/Resume_Files/christopheranderson_8430
#   inflating: data/Resume_Files/ElectricianForeman_8890
#   inflating: data/Resume_Files/OrenBissick_18659
#   inflating: data/Resume_Files/AuditAdministratorQuality_3540
#   inflating: data/Resume_Files/Dispatcher_29991
#   inflating: data/Resume_Files/AdministrativeAssaistant_22428
#   inflating: data/Resume_Files/ChelseaWilliams_40645
#   inflating: data/Resume_Files/TheresaBecker_5178
#   inflating: data/Resume_Files/AndreaIrias_19349
#   inflating: data/Resume_Files/JobSeeker_46497
#   inflating: data/Resume_Files/ChristinaLeMere_24029
#   inflating: data/Resume_Files/FieldTech_15407
#   inflating: data/Resume_Files/ChildCareWorker_16797
#  extracting: data/Resume_Files/LeasingSpecialist_22286
#  extracting: data/Resume_Files/CustomerServiceRep_9144
#   inflating: data/Resume_Files/CertifiedPharmacyTechnician_32689
#   inflating: data/Resume_Files/DamonThomasJr_21279
#   inflating: data/Resume_Files/DanielleQuemada_19399
#   inflating: data/Resume_Files/CustomerServiceRepresentative_14962
#   inflating: data/Resume_Files/Shiftmanager_5599
#   inflating: data/Resume_Files/BanquetServer_16005
#   inflating: data/Resume_Files/JobSeeker_22417
#   inflating: data/Resume_Files/Cashier_16166
#   inflating: data/Resume_Files/JobSeeker_39417
#   inflating: data/Resume_Files/CaseManager_49958
#   inflating: data/Resume_Files/EdwardJohnston_1771
#   inflating: data/Resume_Files/KyleMartin_24312
#   inflating: data/Resume_Files/SeanGatchel_12175
#   inflating: data/Resume_Files/CydneeFord_40412
#   inflating: data/Resume_Files/ResourceAllocation_7110
#   inflating: data/Resume_Files/PaulNorton_23365
#   inflating: data/Resume_Files/AnkitSadana_43577
#   inflating: data/Resume_Files/SalesAssociateIcurrentlysellcellphones_2379
#   inflating: data/Resume_Files/PersonalCareWorker_19731
#   inflating: data/Resume_Files/LibraryAssociate_1738
#   inflating: data/Resume_Files/HeadChef_2961
#   inflating: data/Resume_Files/ProductionEngineerIIIII_11085
#  extracting: data/Resume_Files/StaffRN_45138
#   inflating: data/Resume_Files/DieashaHunt_21478
#   inflating: data/Resume_Files/ShannonEberly_13743
#   inflating: data/Resume_Files/ProjectManager_33948
#   inflating: data/Resume_Files/CashierCustomerService_28058
#   inflating: data/Resume_Files/LateraHodge_5080
#   inflating: data/Resume_Files/MariaWashington_31616
#   inflating: data/Resume_Files/ICFSIRASDATL_49462
#   inflating: data/Resume_Files/AllanStoufer_41866
#   inflating: data/Resume_Files/CallCenterCustomerServiceRepresentative_36156
#   inflating: data/Resume_Files/AnthonyArnold_38535
#   inflating: data/Resume_Files/asiarobinsin_31204
#   inflating: data/Resume_Files/GuestServiceAgent_34696
#   inflating: data/Resume_Files/WilliamGray_22921
#   inflating: data/Resume_Files/CorrineDunkin_19120
#   inflating: data/Resume_Files/ErikaKronenberg_6667
#   inflating: data/Resume_Files/ExecutiveVicePresidentandChiefCreditOfficer_12701
#   inflating: data/Resume_Files/GENERALLABOR_11209
#   inflating: data/Resume_Files/PrivateTutor_15496
#   inflating: data/Resume_Files/RegisteredNurse_36624
#   inflating: data/Resume_Files/DriverforsoutheastUS_8852
#   inflating: data/Resume_Files/TiffanyLyonsAllen_37912
#   inflating: data/Resume_Files/RamzyElTaher_22766
#   inflating: data/Resume_Files/PeterHouston_46341
#   inflating: data/Resume_Files/TransportationAssociate_28895
#  extracting: data/Resume_Files/lead_2296
#   inflating: data/Resume_Files/ProjectManagerEstimator_3136
#   inflating: data/Resume_Files/LaJuanCrumley_38363
#   inflating: data/Resume_Files/Intern_47462
#   inflating: data/Resume_Files/CashierPT_20062
#   inflating: data/Resume_Files/MarkiaBoone_6593
#   inflating: data/Resume_Files/Caregiver_15552
#   inflating: data/Resume_Files/costruction_48270
#   inflating: data/Resume_Files/SalesRepresentative_45768
#   inflating: data/Resume_Files/HyniyfWalthour_9977
#   inflating: data/Resume_Files/JeannetteFigueroa_42098
#   inflating: data/Resume_Files/SummerStudentMaterialHandler_25136
#   inflating: data/Resume_Files/SusanGarnett_17410
#   inflating: data/Resume_Files/AngelinaClark_7436
#   inflating: data/Resume_Files/RoyCollins_38855
#   inflating: data/Resume_Files/CynthiaGonzalez_32368
#   inflating: data/Resume_Files/SalesAssociate_35800
#   inflating: data/Resume_Files/AndreaCampbell_17893
#   inflating: data/Resume_Files/TiffanyConcepcion_37457
#   inflating: data/Resume_Files/QualitySpecialist_3441
#   inflating: data/Resume_Files/TomBattista_14522
#   inflating: data/Resume_Files/SeniorinternationalBuyer_35254
#   inflating: data/Resume_Files/AccountingClerk_25332
#   inflating: data/Resume_Files/ChildPsychiatrist_45235
#   inflating: data/Resume_Files/JeffreyAnderson_9879
#   inflating: data/Resume_Files/SarahSouthernThompson_37450
#   inflating: data/Resume_Files/BryantBrown_38761
#   inflating: data/Resume_Files/BridgettRiley_18336
#   inflating: data/Resume_Files/LindaAleksa_41308
#   inflating: data/Resume_Files/JetaunBlanton_10821
#   inflating: data/Resume_Files/DeborahWhetsel_23617
#   inflating: data/Resume_Files/WelderFabricator_34016
#   inflating: data/Resume_Files/TiffanyMoreno_39779
#   inflating: data/Resume_Files/TEAMLEADERKILLED_17128
#   inflating: data/Resume_Files/ArmedSecurityOfficer_29350
#   inflating: data/Resume_Files/ParamountSeniorLiving_39626
#   inflating: data/Resume_Files/StaffAssistant_10232
#   inflating: data/Resume_Files/INSTRUMENTATIONTECHNICIAN_27961
#   inflating: data/Resume_Files/HaleighShipley_46783
#  extracting: data/Resume_Files/BenefitsAdminister_262
#   inflating: data/Resume_Files/GeneralLaborer_32802
#   inflating: data/Resume_Files/PicassioMcGhee_43765
#   inflating: data/Resume_Files/TechnicalAnalystDeveloperModuleLead_35805
#   inflating: data/Resume_Files/SafetyManager_3700
#   inflating: data/Resume_Files/customerservicerep_35373
#   inflating: data/Resume_Files/NetsanetBoston_23401
#   inflating: data/Resume_Files/ExecutiveSalesAssistant_40767
#   inflating: data/Resume_Files/PATIENTADMISSIONSSUPPORTSPECIALIST_36213
#   inflating: data/Resume_Files/DannyReyes_14683
#   inflating: data/Resume_Files/KamyceDavis_41277
#   inflating: data/Resume_Files/SrOracleSystemAnalyst_39596
#   inflating: data/Resume_Files/AutomotiveLineTechnician_24843
#   inflating: data/Resume_Files/CourtneySpeer_43842
#   inflating: data/Resume_Files/FinancialSpecialist_29694
#   inflating: data/Resume_Files/CenterConsultant_28871
#   inflating: data/Resume_Files/JoselynSimprevil_18300
#   inflating: data/Resume_Files/TelerecruiterforApheresisDepartment_3053
#   inflating: data/Resume_Files/HannahSummers_15140
#   inflating: data/Resume_Files/JoseJuarezHernandez_22702
#   inflating: data/Resume_Files/GrantAdministrator_3651
#   inflating: data/Resume_Files/Telecommutingparalegal_8733
#   inflating: data/Resume_Files/Driver_24575
#   inflating: data/Resume_Files/TeacherAssistant_22226
#   inflating: data/Resume_Files/BiomedicalEquipmentSupportSpecialist_4343
#   inflating: data/Resume_Files/Utilities_44716
#   inflating: data/Resume_Files/Instructor_33897
#   inflating: data/Resume_Files/Caregiver_25434
#   inflating: data/Resume_Files/MaintenanceTechnician_10306
#   inflating: data/Resume_Files/SageHaynicz_46437
#   inflating: data/Resume_Files/AnthonyPerez_18308
#   inflating: data/Resume_Files/GeneralManager_3695
#   inflating: data/Resume_Files/None_28974
#   inflating: data/Resume_Files/CSRCustomerServiceRepresentative_39454
#   inflating: data/Resume_Files/JerrySanders_24072
#   inflating: data/Resume_Files/Associate_9448
#   inflating: data/Resume_Files/ShopForman_35357
#   inflating: data/Resume_Files/BrianWetzel_37613
#   inflating: data/Resume_Files/OperatorManager_19717
#   inflating: data/Resume_Files/Assistresident_15675
#   inflating: data/Resume_Files/sheebragreene_40139
#   inflating: data/Resume_Files/JenniferWatkins_12278
#   inflating: data/Resume_Files/NakiaMitchell_37512
#   inflating: data/Resume_Files/COMPUTERSCIENCETUTOR_3721
#   inflating: data/Resume_Files/HeavyEquipmentOperator_25364
#   inflating: data/Resume_Files/BarbaraAcab_20475
#   inflating: data/Resume_Files/HRLearningandPerformanceAssociate_36158
#   inflating: data/Resume_Files/AccountsPayableCoordinator_35348
#   inflating: data/Resume_Files/Clerk_16618
#   inflating: data/Resume_Files/ShiftManager_8505
#   inflating: data/Resume_Files/KimChinasing_42226
#   inflating: data/Resume_Files/Truckdriver_36426
#   inflating: data/Resume_Files/SeniordesignConsultant_40754
#   inflating: data/Resume_Files/TobiasStay_23407
#   inflating: data/Resume_Files/Robertraigoza_38172
#   inflating: data/Resume_Files/WirelessCareRepresentative_3433
#   inflating: data/Resume_Files/HousngProgramAssitantOfficeSpecialist_35702
#   inflating: data/Resume_Files/JuanitaCrouch_30594
#   inflating: data/Resume_Files/CentralBillingManager_49399
#   inflating: data/Resume_Files/VolunteerWork_33275
#   inflating: data/Resume_Files/MedicalAssistant_48239
#   inflating: data/Resume_Files/WarehouseManager_437
#   inflating: data/Resume_Files/Dishwasher_332
#   inflating: data/Resume_Files/Facilitator_29634
#   inflating: data/Resume_Files/Auditor_25045
#   inflating: data/Resume_Files/AmberLarsen_48974
#   inflating: data/Resume_Files/ChemicalDependencyCounselor_24665
#   inflating: data/Resume_Files/ElaineKane_22670
#   inflating: data/Resume_Files/PersonalCareassistant_10101
#   inflating: data/Resume_Files/Secretary_14849
#   inflating: data/Resume_Files/NoahSpann_7184
#   inflating: data/Resume_Files/JaymeLeupold_38147
#   inflating: data/Resume_Files/KevinKendall_814
#   inflating: data/Resume_Files/SchoolBasedTherapist_3720
#   inflating: data/Resume_Files/CookieDeeLampitco_8038
#   inflating: data/Resume_Files/DanielleHall_36968
#   inflating: data/Resume_Files/CREWMEMBER_11890
#   inflating: data/Resume_Files/StoreManager_44592
#   inflating: data/Resume_Files/ChefdeTournant_42916
#   inflating: data/Resume_Files/NancyMesser_23827
#   inflating: data/Resume_Files/ArmedSecurityGuard_49511
#   inflating: data/Resume_Files/LeadDentalAssistant_35908
#   inflating: data/Resume_Files/SrSystemsTestEngineer_535
#   inflating: data/Resume_Files/CustomerServiceSpecialist3_9134
#   inflating: data/Resume_Files/Pipefitter_3362
#   inflating: data/Resume_Files/JobSeeker_1069
#   inflating: data/Resume_Files/JobSeeker_11350
#   inflating: data/Resume_Files/SelfEmployed_10676
#   inflating: data/Resume_Files/MaricelaOrtega_21518
#   inflating: data/Resume_Files/Cook_43202
#   inflating: data/Resume_Files/RamonMartinez_38412
#   inflating: data/Resume_Files/FULLTIMENETSOFTWAREENGINEERINTERN_17557
#   inflating: data/Resume_Files/AssistantStoreManager_10001
#   inflating: data/Resume_Files/JobSeeker_33523
#   inflating: data/Resume_Files/SafetyRescueTechnician_48079
#   inflating: data/Resume_Files/RobbieFox_37591
#   inflating: data/Resume_Files/Packer_2004
#   inflating: data/Resume_Files/JamesTrosclair_21268
#   inflating: data/Resume_Files/Intern_32646
#   inflating: data/Resume_Files/ClericalAssistant_36194
#   inflating: data/Resume_Files/ShannonCuffia_40230
#   inflating: data/Resume_Files/NataciaCunningham_46976
#   inflating: data/Resume_Files/Cook_10335
#   inflating: data/Resume_Files/kawandamcneil_4174
#   inflating: data/Resume_Files/cleaninghouses_36126
#   inflating: data/Resume_Files/AnnaStoner_24140
#   inflating: data/Resume_Files/AdministrativeAssistant_48601
#   inflating: data/Resume_Files/SalesConsultant_29958
#   inflating: data/Resume_Files/MGRDETAILERCUSTOMERSERVICE_8746
#   inflating: data/Resume_Files/anginiquehatten_18974
#   inflating: data/Resume_Files/KathrynMusterman_32250
#   inflating: data/Resume_Files/JobSeeker_42790
#   inflating: data/Resume_Files/SkilledWarehouseOperator_11923
#   inflating: data/Resume_Files/SalesAssociateCashier_35852
#   inflating: data/Resume_Files/MachinistMateFiremanE3_48679
#   inflating: data/Resume_Files/Bartender_14771
#   inflating: data/Resume_Files/FoodServiceWorker_24904
#   inflating: data/Resume_Files/AlecRecker_13511
#   inflating: data/Resume_Files/BayronGuerra_38062
#   inflating: data/Resume_Files/ConsumerAssistant_47608
#   inflating: data/Resume_Files/DirectorofTechnicalServices_2942
#   inflating: data/Resume_Files/HenryLuna_1229
#   inflating: data/Resume_Files/DianaStrain_13829
#   inflating: data/Resume_Files/JobSeeker_10117
#   inflating: data/Resume_Files/ElenitaCleveland_18385
#   inflating: data/Resume_Files/DamienBuggs_19844
#   inflating: data/Resume_Files/AshleyBradley_38249
#   inflating: data/Resume_Files/PreschoolTeachersAide_33769
#   inflating: data/Resume_Files/TemporaryAgencys_35215
#   inflating: data/Resume_Files/JobSeeker_39458
#   inflating: data/Resume_Files/MelissaMabb_13993
#   inflating: data/Resume_Files/SandraHernandez_45649
#   inflating: data/Resume_Files/AJCzarnecki_800
#   inflating: data/Resume_Files/MallikV_12061
#   inflating: data/Resume_Files/JamesReardon_31511
#   inflating: data/Resume_Files/RayCryer_4561
#   inflating: data/Resume_Files/FrontDeskReceptionist_44765
#   inflating: data/Resume_Files/Verifierauditor_9246
#   inflating: data/Resume_Files/Server_8894
#   inflating: data/Resume_Files/Materialhandler_11303
#   inflating: data/Resume_Files/ServiceTechnician_33954
#   inflating: data/Resume_Files/Cook_24741
#   inflating: data/Resume_Files/WaiterHost_29103
#   inflating: data/Resume_Files/SarahGreen_1619
#   inflating: data/Resume_Files/RoselynRittenour_12964
#   inflating: data/Resume_Files/StephaniePage_26854
#   inflating: data/Resume_Files/JobSeeker_42885
#   inflating: data/Resume_Files/BudgetAnalyst_39201
#   inflating: data/Resume_Files/MarieCartwright_41415
#   inflating: data/Resume_Files/AssemblyLineWorker_12487
#   inflating: data/Resume_Files/Cashier_1921
#   inflating: data/Resume_Files/AmandaForrest_19421
#   inflating: data/Resume_Files/RobertaBursey_20536
#   inflating: data/Resume_Files/Server_34512
#   inflating: data/Resume_Files/BoardMember_12659
#   inflating: data/Resume_Files/AutomotiveDetailing_215
#   inflating: data/Resume_Files/PatientSafetyAttendant_14855
#   inflating: data/Resume_Files/ReferralCoordinatorMedicalRecordsClerk_14900
#   inflating: data/Resume_Files/JuliannPerez_40389
#   inflating: data/Resume_Files/DomoniqueHatch_18007
#   inflating: data/Resume_Files/QualityManager_34642
#   inflating: data/Resume_Files/Landscaping_16679
#   inflating: data/Resume_Files/AndreCranmer_42080
#   inflating: data/Resume_Files/KaylaniraeWellsLongshore_41367
#   inflating: data/Resume_Files/ShellyCortez_20315
#   inflating: data/Resume_Files/CherylJames_21162
#   inflating: data/Resume_Files/GerVang_18939
#   inflating: data/Resume_Files/DirectorofOperations_49545
#   inflating: data/Resume_Files/KacyCurtis_37807
#   inflating: data/Resume_Files/AnnaRowe_27261
#   inflating: data/Resume_Files/JOBDEVELOPMENTSPECIALIST_41159
#   inflating: data/Resume_Files/BevCantrell_38828
#   inflating: data/Resume_Files/DeputySheriffLieutenant_47723
#   inflating: data/Resume_Files/SarahTurnage_6720
#   inflating: data/Resume_Files/VeronicaSkala_21761
#   inflating: data/Resume_Files/DonaldWright_30443
#   inflating: data/Resume_Files/InsuranceConsultant_25372
#   inflating: data/Resume_Files/TaylorSawyer_37635
#   inflating: data/Resume_Files/GraduateTeachingAssistant_9669
#   inflating: data/Resume_Files/OnCallCustodian_24954
#   inflating: data/Resume_Files/JosephQuirino_48764
#   inflating: data/Resume_Files/GlobalProcessEngineeringDirector_25356
#   inflating: data/Resume_Files/PTMerchandiser_25111
#   inflating: data/Resume_Files/Journeymanmailermachinistoperator_17202
#   inflating: data/Resume_Files/MartiaJones_18118
#   inflating: data/Resume_Files/BenBaker_9789
#   inflating: data/Resume_Files/KennelAssistantGroomingAssistant_36433
#   inflating: data/Resume_Files/RampAgent_47486
#   inflating: data/Resume_Files/CustomerServiceRepresentative_32244
#   inflating: data/Resume_Files/ShiftLeader_16877
#   inflating: data/Resume_Files/DeliveryDriver_47977
#   inflating: data/Resume_Files/RedCrossVolunteer_28584
#   inflating: data/Resume_Files/KiaraRoundtree_13256
#   inflating: data/Resume_Files/HomeInspector_15615
#   inflating: data/Resume_Files/AVTechnicianIntern_11206
#   inflating: data/Resume_Files/DavidCiola_1839
#   inflating: data/Resume_Files/JulioRoberts_36803
#   inflating: data/Resume_Files/HomeHealthAide_30094
#   inflating: data/Resume_Files/CashierCustomerService_5711
#   inflating: data/Resume_Files/ChristopherStewart_12293
#   inflating: data/Resume_Files/SalesAssociate_22422
#  extracting: data/Resume_Files/Manager_44942
#   inflating: data/Resume_Files/Craneoperator_8347
#   inflating: data/Resume_Files/BarbaraRussell_45577
#   inflating: data/Resume_Files/KevinFaviana_12295
#   inflating: data/Resume_Files/SENIORADVISOR_16343
#   inflating: data/Resume_Files/WeekendCashier_46594
#   inflating: data/Resume_Files/marylowry_7667
#   inflating: data/Resume_Files/TECHNICALSUPPORTSPECIALIST_6079
#   inflating: data/Resume_Files/WarehouseWorker_27559
#   inflating: data/Resume_Files/SusanStrohl_6607
#   inflating: data/Resume_Files/MentalHealthSkillBuildingeducationcounselor_29948
#   inflating: data/Resume_Files/TammiSumrall_42153
#   inflating: data/Resume_Files/Chelseaflenmings_7307
#   inflating: data/Resume_Files/EquipmentOperator_548
#   inflating: data/Resume_Files/HectorQuinones_25661
#   inflating: data/Resume_Files/FBarcelÃ³_37607
#   inflating: data/Resume_Files/JanpierreColon_7200
#   inflating: data/Resume_Files/TeamMember_3974
#   inflating: data/Resume_Files/DerrickMitchell_48811
#   inflating: data/Resume_Files/SalesAssociate_15049
#   inflating: data/Resume_Files/Receptionist_15370
#   inflating: data/Resume_Files/Cashier_6018
#   inflating: data/Resume_Files/Electrolux_22122
#   inflating: data/Resume_Files/ChaplainsAssitant_3388
#   inflating: data/Resume_Files/DoraHarris_17875
#   inflating: data/Resume_Files/CoryGosnell_36726
#   inflating: data/Resume_Files/Laborer_33802
#   inflating: data/Resume_Files/officemanager_34802
#   inflating: data/Resume_Files/PatientAccountRepresentativeBusinessdept_35910
#   inflating: data/Resume_Files/UtilityClerk_28721
#   inflating: data/Resume_Files/HaroldBesosa_41257
#   inflating: data/Resume_Files/BridgetSparrow_27369
#   inflating: data/Resume_Files/DoreneCunningham_4069
#   inflating: data/Resume_Files/DistrictMgrover10_224
#   inflating: data/Resume_Files/DietaryAid_35944
#   inflating: data/Resume_Files/RadiologicTechnologist_22349
#   inflating: data/Resume_Files/PackageHandler_25083
#   inflating: data/Resume_Files/LegalAssistantParalegal_5554
#   inflating: data/Resume_Files/VictoriaAndrews_23649
#   inflating: data/Resume_Files/CoreyBressler_41754
#   inflating: data/Resume_Files/StockerCustomerService_45357
#   inflating: data/Resume_Files/AssistantResidentialCoordinator_1809
#   inflating: data/Resume_Files/RegisteredRespiratoryTherapist_6144
#   inflating: data/Resume_Files/HeadCashier_35079
#   inflating: data/Resume_Files/InformationSystemsCoordinator_14978
#   inflating: data/Resume_Files/Cashier_11321
#   inflating: data/Resume_Files/FlowTeamMember_43439
#   inflating: data/Resume_Files/DirectorofECommerceMarketing_40771
#   inflating: data/Resume_Files/SalesManagerPreownedMgrBusinessManager_34314
#   inflating: data/Resume_Files/ForwardLogisticsSpecialist_34894
#   inflating: data/Resume_Files/PryceCha_19388
#   inflating: data/Resume_Files/RegisteredNurse_28557
#   inflating: data/Resume_Files/JobSeeker_4277
#   inflating: data/Resume_Files/KatherineAdams_42412
#   inflating: data/Resume_Files/BethSheldon_24000
#   inflating: data/Resume_Files/Assistantstoremanager_15850
#   inflating: data/Resume_Files/HumanResourcesOnboardingCoordinator_9196
#   inflating: data/Resume_Files/PaulaCooper_20077
#   inflating: data/Resume_Files/JobSeeker_44723
#   inflating: data/Resume_Files/AdministrativeAssistant_40936
#   inflating: data/Resume_Files/UXDesigner_10936
#   inflating: data/Resume_Files/AmberSutherlandDunkins_30350
#   inflating: data/Resume_Files/LPN_34086
#   inflating: data/Resume_Files/tremainejyles_48933
#   inflating: data/Resume_Files/AdmissionNurse_15629
#   inflating: data/Resume_Files/PayrollClerk_43365
#   inflating: data/Resume_Files/JobSeeker_32201
#   inflating: data/Resume_Files/RegisteredNursecardiaccatheterizationlabrecovery_3496
#   inflating: data/Resume_Files/sierraStorms_15208
#   inflating: data/Resume_Files/Teller_14732
#   inflating: data/Resume_Files/KeyHolderSalesLead_24940
#   inflating: data/Resume_Files/FitnessCenterReceptionist_40888
#   inflating: data/Resume_Files/DistrictManager_42853
#   inflating: data/Resume_Files/OscarQuintero_13012
#   inflating: data/Resume_Files/MikeCable_47102
#   inflating: data/Resume_Files/RECEPTIONISTMASSAGETHERAPIST_35484
#   inflating: data/Resume_Files/JobSeeker_34047
#   inflating: data/Resume_Files/RichardWolff_41433
#   inflating: data/Resume_Files/ArielMurphy_1226
#   inflating: data/Resume_Files/ConstructionWorker_28866
#   inflating: data/Resume_Files/RonaldLambert_23107
#   inflating: data/Resume_Files/FrontDeskReceptionist_29099
#   inflating: data/Resume_Files/DirectSupportProfessionalDSP_25199
#   inflating: data/Resume_Files/Culinarycook_27743
#   inflating: data/Resume_Files/BessiChavez_42095
#   inflating: data/Resume_Files/MechanicPumpcoSuperiorEnergyIntl_49811
#   inflating: data/Resume_Files/TaylorChibatto_47145
#   inflating: data/Resume_Files/Host_28873
#   inflating: data/Resume_Files/DeborahCasey_23086
#   inflating: data/Resume_Files/DatabasemanagementandAdministrator_35888
#   inflating: data/Resume_Files/Sweeper_27545
#   inflating: data/Resume_Files/SeasonalBookstoreClerkCashier_1939
#   inflating: data/Resume_Files/MeghaAggarwal_25822
#   inflating: data/Resume_Files/OwnerandOperator_29819
#   inflating: data/Resume_Files/StephanieStevens_38061
#   inflating: data/Resume_Files/JohnQuinlan_41504
#   inflating: data/Resume_Files/EustaceCastellaneta_41365
#   inflating: data/Resume_Files/ClientInformationDatabaseSteward_33228
#   inflating: data/Resume_Files/ShippingCoordinatorAugust_30061
#   inflating: data/Resume_Files/JobSeeker_15279
#   inflating: data/Resume_Files/Fullservicemarketing_8872
#   inflating: data/Resume_Files/AngelSantos_47170
#   inflating: data/Resume_Files/HealthCare_33133
#   inflating: data/Resume_Files/WarehouseAssociateForkliftOperator_42923
#   inflating: data/Resume_Files/Housekeeping_35806
#   inflating: data/Resume_Files/IndependentContractor_15789
#   inflating: data/Resume_Files/LPN_44213
#   inflating: data/Resume_Files/PhoneSurveyor_29853
#   inflating: data/Resume_Files/EricHatchett_7597
#   inflating: data/Resume_Files/RobinFeret_21394
#   inflating: data/Resume_Files/AdmissionsRepresentative_10757
#   inflating: data/Resume_Files/Dispatcher_28208
#   inflating: data/Resume_Files/KyleHawkins_38818
#   inflating: data/Resume_Files/StaceyPritchett_7816
#   inflating: data/Resume_Files/production_49372
#   inflating: data/Resume_Files/ShaylynnHutchings_46955
#   inflating: data/Resume_Files/Generallaborer_15459
#   inflating: data/Resume_Files/LaGariusTalbert_23367
#   inflating: data/Resume_Files/MedicalSecretaryforFamilyPracticePhysicians_5654
#   inflating: data/Resume_Files/SeniorPastor_11703
#   inflating: data/Resume_Files/LindellGiles_31009
#   inflating: data/Resume_Files/GraphicDesignerPhotographer_49152
#   inflating: data/Resume_Files/ITSPECIALIST_43157
#   inflating: data/Resume_Files/pos_28577
#   inflating: data/Resume_Files/AlexMitchell_26915
#   inflating: data/Resume_Files/FulltimeStudent_24869
#   inflating: data/Resume_Files/COO_42786
#   inflating: data/Resume_Files/BarrianRoberts_14103
#   inflating: data/Resume_Files/JuniorAccountExecutiveIntern_2617
#   inflating: data/Resume_Files/KeithAdcock_7370
#   inflating: data/Resume_Files/janitorpainter_9951
#   inflating: data/Resume_Files/Researcher_11774
#   inflating: data/Resume_Files/AssetProtectionSpecialist_48580
#   inflating: data/Resume_Files/Carpenter_4040
#   inflating: data/Resume_Files/ChildcareProvider_50000
#   inflating: data/Resume_Files/Painter_44826
#   inflating: data/Resume_Files/DirectorofProductDevelopment_22403
#   inflating: data/Resume_Files/BrandMarketingSeniorContractor_47687
#   inflating: data/Resume_Files/CoreyOShea_48882
#   inflating: data/Resume_Files/AssistantManager_3988
#   inflating: data/Resume_Files/NormaMorgan_9454
#   inflating: data/Resume_Files/ReceptionistBookkeeper_15318
#   inflating: data/Resume_Files/KellyRice_17716
#   inflating: data/Resume_Files/TechnicalSupport_32222
#   inflating: data/Resume_Files/DawnRibeiro_46977
#   inflating: data/Resume_Files/Diamondhead_32714
#   inflating: data/Resume_Files/CrewMember_10383
#   inflating: data/Resume_Files/Teacher_47842
#   inflating: data/Resume_Files/RachelShaefer_27016
#   inflating: data/Resume_Files/AngelaPaxton_21195
#   inflating: data/Resume_Files/marcusstrickland_27341
#   inflating: data/Resume_Files/JobSeeker_40722
#   inflating: data/Resume_Files/CarolJosephs_38060
#   inflating: data/Resume_Files/JobSeeker_27711
#  extracting: data/Resume_Files/UnderwritingAssistant_3096
#   inflating: data/Resume_Files/ErikaWine_18709
#   inflating: data/Resume_Files/FoodSafetyandQualityAssuranceManger_45377
#   inflating: data/Resume_Files/FrontDeskReceptionist_1979
#   inflating: data/Resume_Files/CamilLewis_26109
#   inflating: data/Resume_Files/ChrizaTimagos_14554
#   inflating: data/Resume_Files/SERVER_34052
#   inflating: data/Resume_Files/ChadRunt_25658
#   inflating: data/Resume_Files/JeffUlery_13347
#  extracting: data/Resume_Files/ChefdePartie_22211
#   inflating: data/Resume_Files/AngelaJohnson_26800
#   inflating: data/Resume_Files/OctaviaWalker_12065
#   inflating: data/Resume_Files/NPDEngineerAerospace_49862
#   inflating: data/Resume_Files/TiaraRichardson_18432
#  extracting: data/Resume_Files/CofounderCEO_17442
#  extracting: data/Resume_Files/Counselor_33725
#   inflating: data/Resume_Files/JacqulynPaigeThompson_41473
#   inflating: data/Resume_Files/CharleneDelarosa_38539
#   inflating: data/Resume_Files/MakebraGardner_19812
#   inflating: data/Resume_Files/MaterialandCarouselHandler_29504
#   inflating: data/Resume_Files/TabithaTrotter_47127
#   inflating: data/Resume_Files/VirtualInternationalBusinessMarketingIntern_29823
#   inflating: data/Resume_Files/AlyssaGuinn_15220
#   inflating: data/Resume_Files/Assoicateresolvedcustomercomplainspromptlyandprofessionally_39473
#   inflating: data/Resume_Files/LauraBaldwin_41610
#   inflating: data/Resume_Files/Stocker_49446
#   inflating: data/Resume_Files/AudreyAllison_19365
#   inflating: data/Resume_Files/JobSeeker_29855
#   inflating: data/Resume_Files/RyanSchlager_20451
#   inflating: data/Resume_Files/JillHasier_48798
#   inflating: data/Resume_Files/CoordinatorScheduler_29950
#   inflating: data/Resume_Files/ParisWhitehead_38871
#   inflating: data/Resume_Files/RasheedStevens_31038
#   inflating: data/Resume_Files/LicensedInsuranceAgent_47551
#   inflating: data/Resume_Files/Sandwichmaker_36445
#   inflating: data/Resume_Files/NMUGolfCourseStaff_5827
#   inflating: data/Resume_Files/KaileeGeminick_6358
#   inflating: data/Resume_Files/MichelleHamer_4566
#   inflating: data/Resume_Files/ClintonBrownlee_14417
#   inflating: data/Resume_Files/LollyAnderson_26129
#   inflating: data/Resume_Files/JeffreyBaril_18267
#   inflating: data/Resume_Files/FieldServiceRepresentative_8601
#   inflating: data/Resume_Files/DanMcCall_46980
#   inflating: data/Resume_Files/RECRUITINGCOORDINATORCONTRACTTOPERMANENT_3906
#   inflating: data/Resume_Files/NdipenochLebsiaekamdem_744
#  extracting: data/Resume_Files/MerchandisingAssistantStoreManager_34806
#   inflating: data/Resume_Files/TitleClerk_47280
#   inflating: data/Resume_Files/JobSeeker_16106
#   inflating: data/Resume_Files/LeeEisenhardt_14681
#   inflating: data/Resume_Files/UnderthesupervisionoftheLifeSupportSupervisor_3284
#   inflating: data/Resume_Files/TechnicalSupport_3118
#   inflating: data/Resume_Files/MarlieDelisfort_22840
#   inflating: data/Resume_Files/SyedFahadShaw_42278
#   inflating: data/Resume_Files/Teamleadondesigning2ndprototypethermosiphon_16785
#   inflating: data/Resume_Files/ZachDodd_18221
#   inflating: data/Resume_Files/SalesAssociate_16615
#   inflating: data/Resume_Files/ElaineAlvarez_37782
#   inflating: data/Resume_Files/ReservationsSpecialist_49906
#   inflating: data/Resume_Files/VicePresidentInformationSecurityOfficer_22260
#   inflating: data/Resume_Files/JavierNolasco_17915
#   inflating: data/Resume_Files/JosephCasias_23508
#   inflating: data/Resume_Files/JobSeeker_4495
#   inflating: data/Resume_Files/MikeEverhart_14696
#   inflating: data/Resume_Files/BuildingManager_34636
#   inflating: data/Resume_Files/JobSeeker_17782
#   inflating: data/Resume_Files/KimberlyLuczkowski_23275
#   inflating: data/Resume_Files/Housekeeper_8962
#   inflating: data/Resume_Files/MarketingManager_15626
#   inflating: data/Resume_Files/DirectCarePerson_2570
#   inflating: data/Resume_Files/ShiftLieutenant_36616
#   inflating: data/Resume_Files/LakenziReel_6691
#   inflating: data/Resume_Files/Cashiersalesassociate_43514
#   inflating: data/Resume_Files/SoftwareEngineer_5242
#   inflating: data/Resume_Files/JeramieBussard_27129
#   inflating: data/Resume_Files/utilities_16437
#   inflating: data/Resume_Files/CarlaBrown_30405
#   inflating: data/Resume_Files/jeffreypyatte_4730
#   inflating: data/Resume_Files/AlexiaAdkins_7668
#   inflating: data/Resume_Files/JosephWible_37614
#   inflating: data/Resume_Files/JonnathanBurgos_41872
#   inflating: data/Resume_Files/Assenbler3_36104
#   inflating: data/Resume_Files/OrthodonticAssistant_35543
#   inflating: data/Resume_Files/RennieAbraham_21105
#   inflating: data/Resume_Files/HayleyHoffman_23817
#   inflating: data/Resume_Files/JobSeeker_47568
#   inflating: data/Resume_Files/CorettaRandolph_7023
#   inflating: data/Resume_Files/ResourceHealthUnitCoordinatior_34062
#   inflating: data/Resume_Files/FelishaDonerson_14070
#   inflating: data/Resume_Files/LocksmithA_34280
# ...
#   inflating: data/Resume_Files/EveningShiftSupervisorcook_24824
#   inflating: data/Resume_Files/NicholeReyes_38716
#   inflating: data/Resume_Files/ReceptionistMedicalSecretaryCardiology_16405
#   inflating: data/Resume_Files/JessicaPost_9685
#   inflating: data/Resume_Files/RyanSpringsteen_43886
#   inflating: data/Resume_Files/TechnicalAnalyst_39203
#   inflating: data/Resume_Files/ShirleyRoyer_26482
#   inflating: data/Resume_Files/CustomerService_3317
#   inflating: data/Resume_Files/RamonKneeland_8055
#   inflating: data/Resume_Files/PhysicalTherapist_42555
#   inflating: data/Resume_Files/Managermechanicalequipmentintherollingmills_40852
#   inflating: data/Resume_Files/MaterialManagementBackchargeandLogisticsCoordinatorWarehouseSupervisor_3154
#   inflating: data/Resume_Files/IllinoisFarmersInsuranceAgencyLifeInsuranceSpecialist_43680
#   inflating: data/Resume_Files/WilliePreyer_31178
#   inflating: data/Resume_Files/GradeTeacherK5_49120
#   inflating: data/Resume_Files/NannySupportWorker_34542
#   inflating: data/Resume_Files/ResidentAssistant_47895
#   inflating: data/Resume_Files/EDTechnician_17365
#   inflating: data/Resume_Files/PurchasingAgentSeniorBartenderFBManager_29364
#   inflating: data/Resume_Files/PaulCole_39734
#   inflating: data/Resume_Files/Inflatablecastleattendant_11743
#   inflating: data/Resume_Files/LubeTechnician_35529
#   inflating: data/Resume_Files/CreatedQA_32427
#   inflating: data/Resume_Files/JamesMarion_38756
#   inflating: data/Resume_Files/KeowandaHopkins_7728
#   inflating: data/Resume_Files/QuinnCollins_15161
#   inflating: data/Resume_Files/Custodian_36580
#   inflating: data/Resume_Files/CrewMember_16283
#   inflating: data/Resume_Files/Server_14907
#   inflating: data/Resume_Files/ManagerGraphicDesigner_9824
#   inflating: data/Resume_Files/TiffanyCooper_37186
#   inflating: data/Resume_Files/VelmaHilton_20157
#   inflating: data/Resume_Files/StevenVentura_9937
#   inflating: data/Resume_Files/KenyaSprouse_21484
#   inflating: data/Resume_Files/JasonPowell_6763
#   inflating: data/Resume_Files/AntionetteShaw_9539
#   inflating: data/Resume_Files/EngineeringIntern_16168
#   inflating: data/Resume_Files/Housekeeper_10205
#   inflating: data/Resume_Files/CustomerServiceRepresentative_11624
#   inflating: data/Resume_Files/ValetParking_5521
#   inflating: data/Resume_Files/SteveWeiner_27222
#  extracting: data/Resume_Files/Dispatcher_11417
#   inflating: data/Resume_Files/VolunteerLibraryAid_5826
#   inflating: data/Resume_Files/MichaelWade_20396
#   inflating: data/Resume_Files/AllieDierschke_4193
#   inflating: data/Resume_Files/MelissaZamora_41655
#   inflating: data/Resume_Files/DraftsmanDesigner_24909
#   inflating: data/Resume_Files/CameraCarDriver_36545
#   inflating: data/Resume_Files/MaintenanceSpecialistLead_8392
#   inflating: data/Resume_Files/RanjithCheprolu_4459
#   inflating: data/Resume_Files/MarkeshaBrown_8162
#   inflating: data/Resume_Files/LisaWells_13250
#   inflating: data/Resume_Files/EdiaAntoine_40403
#   inflating: data/Resume_Files/OFFICEASSISTANT_33483
#   inflating: data/Resume_Files/PattiJoKosinski_30205
#   inflating: data/Resume_Files/Roberthough_897
#   inflating: data/Resume_Files/TishaWicks_31245
#   inflating: data/Resume_Files/ResearchAnalyst_11943
#   inflating: data/Resume_Files/CarolFobes_7007
#   inflating: data/Resume_Files/SamanthaSuddoth_12972
#   inflating: data/Resume_Files/JobSeeker_3661
#   inflating: data/Resume_Files/HumanResourcesGeneralist_11524
#   inflating: data/Resume_Files/ProductionCoordinator_49291
#   inflating: data/Resume_Files/RandiFuller_21745
#   inflating: data/Resume_Files/VidyaRamanathan_14081
#   inflating: data/Resume_Files/DENTALASSISTANT_11323
#   inflating: data/Resume_Files/LindsayMagnuson_42184
#   inflating: data/Resume_Files/JobSeeker_11535
#   inflating: data/Resume_Files/Supervisor_2969
#   inflating: data/Resume_Files/JarretMcKinstry_20896
#   inflating: data/Resume_Files/JoseVelez_19491
#   inflating: data/Resume_Files/HumanResourceSpecialist_694
#   inflating: data/Resume_Files/JaronWitt_14494
#   inflating: data/Resume_Files/StevenAddis_31757
#   inflating: data/Resume_Files/StevenThornton_23634
#   inflating: data/Resume_Files/MichaelWei_19304
#   inflating: data/Resume_Files/Sweingmachineoperator_32921
#   inflating: data/Resume_Files/JobSeeker_19653
#   inflating: data/Resume_Files/Houseman_49732
#   inflating: data/Resume_Files/WilliamFairbairn_27058
#   inflating: data/Resume_Files/RickKimmel_7902
#   inflating: data/Resume_Files/Sawyer_3769
#   inflating: data/Resume_Files/CassandraWilson_13110
#   inflating: data/Resume_Files/Securityofficer_49081
#   inflating: data/Resume_Files/MarquisJohnson_849
#   inflating: data/Resume_Files/JosephVieyra_21339
#   inflating: data/Resume_Files/MichaelMurphy_21558
#   inflating: data/Resume_Files/ParamedicDispatcher_3740
#   inflating: data/Resume_Files/ChenKong_37114
#   inflating: data/Resume_Files/forkliftoperator_35423
#   inflating: data/Resume_Files/CynthiaBristow_36971
#   inflating: data/Resume_Files/WilliamHicks_5185
#   inflating: data/Resume_Files/miriamtorres_36998
#   inflating: data/Resume_Files/PortSuperintendent_11277
#   inflating: data/Resume_Files/RossellaTucker_13222
#   inflating: data/Resume_Files/SusanHeidel_30936
#   inflating: data/Resume_Files/FieldServiceManager_39698
#   inflating: data/Resume_Files/AustinFreeman_27245
#   inflating: data/Resume_Files/ChristopherGregory_20420
#   inflating: data/Resume_Files/Caregiver_11026
#   inflating: data/Resume_Files/StoreManager_24682
#   inflating: data/Resume_Files/KelleyVance_25914
#   inflating: data/Resume_Files/StructuralWelder_3251
#   inflating: data/Resume_Files/JanahBrown_38437
#   inflating: data/Resume_Files/VikramBhatla_19463
#   inflating: data/Resume_Files/CoalTruckDriver_33042
#   inflating: data/Resume_Files/RobertSpecht_14319
#   inflating: data/Resume_Files/AngelaDukes_20542
#   inflating: data/Resume_Files/MaintenanceWorker_29935
#   inflating: data/Resume_Files/AshleyBanner_26274
#   inflating: data/Resume_Files/Assembler_24686
#   inflating: data/Resume_Files/ByronHardy_12174
#   inflating: data/Resume_Files/MikeAdkins_797
#   inflating: data/Resume_Files/ReneeBorg_14585
#  extracting: data/Resume_Files/Material_34446
#   inflating: data/Resume_Files/ASSISTANTMANAGER_22269
#   inflating: data/Resume_Files/ShekeelaGaither_30642
#   inflating: data/Resume_Files/LabAssistant_3003
#   inflating: data/Resume_Files/BrittneyPasikowski_46805
#   inflating: data/Resume_Files/MatthewChu_20343
#   inflating: data/Resume_Files/JobSeeker_45987
#   inflating: data/Resume_Files/SantasiaMoore_38057
#   inflating: data/Resume_Files/DouglasHavens_15118
#   inflating: data/Resume_Files/ShaqurahJohnson_45421
#   inflating: data/Resume_Files/JobSeeker_28998
#   inflating: data/Resume_Files/TrialandLitigationAttorney_33109
#  extracting: data/Resume_Files/MassageTherapist_47297
#   inflating: data/Resume_Files/equipmentoperator_44888
#   inflating: data/Resume_Files/CesarVasquezSuarez_48787
#   inflating: data/Resume_Files/TiffanyPaschal_19850
#   inflating: data/Resume_Files/ProfessorofEmeritus_29773
#   inflating: data/Resume_Files/LPNChargeNurse_3021
#   inflating: data/Resume_Files/MiriamPope_21143
#   inflating: data/Resume_Files/CSR_2474
#   inflating: data/Resume_Files/BinCao_39748
#   inflating: data/Resume_Files/NikitaTembo_41848
#   inflating: data/Resume_Files/ComputerAssist_44930
#   inflating: data/Resume_Files/CashierCustomerService_48484
#   inflating: data/Resume_Files/AccountManager_48026
#   inflating: data/Resume_Files/AngelaRossi_13909
#   inflating: data/Resume_Files/VeterinaryTechnician_14840
#   inflating: data/Resume_Files/MedicalRecordsManager_30139
#   inflating: data/Resume_Files/RahulMukundan_25829
#   inflating: data/Resume_Files/DPT_33244
#   inflating: data/Resume_Files/RotatingEquipmentLead_3176
#   inflating: data/Resume_Files/Deliworker_15495
#   inflating: data/Resume_Files/ServerBartenderBrandambassador_6297
#   inflating: data/Resume_Files/JosephHans_22512
#   inflating: data/Resume_Files/JamesTownsend_4801
#   inflating: data/Resume_Files/RosetteDaniel_7930
#   inflating: data/Resume_Files/BiomedEquipmentTechnicianClinicalEngineer_47563
#   inflating: data/Resume_Files/InsuranceAgent_16890
#   inflating: data/Resume_Files/ShippingandReceivingQualityInspector_36658
#   inflating: data/Resume_Files/AndreaBurrell_17674
#   inflating: data/Resume_Files/MentorCNACertifiedNursingAssistant_36124
#   inflating: data/Resume_Files/BusOperator_43191
#   inflating: data/Resume_Files/PRODUCER_2520
#   inflating: data/Resume_Files/TruckLoaderUnloader_15948
#   inflating: data/Resume_Files/patrickreeves_41266
#   inflating: data/Resume_Files/Cashier_47438
#   inflating: data/Resume_Files/ArnoldMarzan_18705
#   inflating: data/Resume_Files/LonnieMcDowell_13679
#   inflating: data/Resume_Files/BillingClerk_16171
#   inflating: data/Resume_Files/CoryBurns_26990
#   inflating: data/Resume_Files/KatelynPhillips_42366
#   inflating: data/Resume_Files/EmanuelThorpe_44223
#  extracting: data/Resume_Files/MedicalAssistant_44913
#   inflating: data/Resume_Files/WarehouseAssociate_15285
#   inflating: data/Resume_Files/RandyCastillo_30400
#   inflating: data/Resume_Files/dishes_28247
#   inflating: data/Resume_Files/TylerSpear_30858
#   inflating: data/Resume_Files/LeliaJackson_4129
#   inflating: data/Resume_Files/InteriorDesigner_16196
#   inflating: data/Resume_Files/MedicalRecordsAuditor3monthcontractjob_42615
#   inflating: data/Resume_Files/MarcellousMontgomery_38379
#   inflating: data/Resume_Files/JobSeeker_11111
#   inflating: data/Resume_Files/SupervisorJustinAugustAngelaBuckland_46557
#   inflating: data/Resume_Files/RebeccaFentzlaff_13890
#   inflating: data/Resume_Files/ResearchAssistant_16926
#   inflating: data/Resume_Files/KristinSauter_42310
#   inflating: data/Resume_Files/QuentinPowers_31804
#   inflating: data/Resume_Files/DanielleHiltibidal_19458
#   inflating: data/Resume_Files/FreePeopleSpecialist_33177
#   inflating: data/Resume_Files/JobSeeker_11773
#   inflating: data/Resume_Files/ShippingAssociate_8632
#   inflating: data/Resume_Files/Cashier_42950
#   inflating: data/Resume_Files/EricLutz_41364
#   inflating: data/Resume_Files/JenniferLuu_6313
#   inflating: data/Resume_Files/SupportSpecialistTechSBiLingual_49803
#  extracting: data/Resume_Files/EmploymentSpecialist_35766
#   inflating: data/Resume_Files/ScottStevens_30361
#   inflating: data/Resume_Files/LauraRodriguez_18828
#   inflating: data/Resume_Files/NicholasCasale_25989
#   inflating: data/Resume_Files/AssistantProfessor_8685
#   inflating: data/Resume_Files/TylerMobley_36952
#   inflating: data/Resume_Files/SlavenaHarrell_6482
#   inflating: data/Resume_Files/Onlinesales_28085
#   inflating: data/Resume_Files/NicoleLapic_40149
#   inflating: data/Resume_Files/DariusKimble_10848
#   inflating: data/Resume_Files/CostControlAnalyst_2939
#   inflating: data/Resume_Files/LogisticsSpecialistForkliftOperator_33419
#   inflating: data/Resume_Files/Counselor_32139
#   inflating: data/Resume_Files/NatashaKing_7890
#   inflating: data/Resume_Files/KimRewa_30210
#   inflating: data/Resume_Files/carlielabitad_6645
#   inflating: data/Resume_Files/RNSupervisor_36085
#   inflating: data/Resume_Files/FreelanceWriter_48360
#   inflating: data/Resume_Files/JamieSmith_37805
#   inflating: data/Resume_Files/Humanresource_36307
#   inflating: data/Resume_Files/JobSeeker_47484
#   inflating: data/Resume_Files/JobSeeker_32842
#   inflating: data/Resume_Files/weldeerpipe_12007
#   inflating: data/Resume_Files/AmberPartin_31057
#   inflating: data/Resume_Files/CustomerServiceRepresentative_35255
#   inflating: data/Resume_Files/TarynFisherMarcy_4271
#   inflating: data/Resume_Files/TravisSeawell_24027
#   inflating: data/Resume_Files/ExecutiveSupportSpecialistExecutiveAdministrativeAssistant_10170
#   inflating: data/Resume_Files/OutreachandEducationalSpecialist_22147
#  extracting: data/Resume_Files/FelixBenavides_48823
#   inflating: data/Resume_Files/Locator_8342
#   inflating: data/Resume_Files/CarolynButler_17780
#   inflating: data/Resume_Files/JobSeeker_10685
#   inflating: data/Resume_Files/JaclynJones_31090
#   inflating: data/Resume_Files/ResidentMonitor_14891
#   inflating: data/Resume_Files/DocumentControlClerk_17338
#   inflating: data/Resume_Files/supervisor_8278
#   inflating: data/Resume_Files/BethanyInniss_46140
#   inflating: data/Resume_Files/ApparelAssociate_24964
#   inflating: data/Resume_Files/MerchandiserRetailRepresentative_8645
#   inflating: data/Resume_Files/NightMangerHeadNightBartender_32423
#   inflating: data/Resume_Files/HRAssistant_12500
#   inflating: data/Resume_Files/PatrickTitus_13830
#   inflating: data/Resume_Files/StevelandLyons_27042
#   inflating: data/Resume_Files/JuniorMerchandiser_16094
#   inflating: data/Resume_Files/Server_28902
#   inflating: data/Resume_Files/LeadBartender_28752
#   inflating: data/Resume_Files/CAREGIVER_24565
#   inflating: data/Resume_Files/YolandaSalinas_7101
#   inflating: data/Resume_Files/Manager_43562
#   inflating: data/Resume_Files/SuperiaGreen_10045
#   inflating: data/Resume_Files/HomeHealthAide_47489
#   inflating: data/Resume_Files/LeadMan_32758
#   inflating: data/Resume_Files/AssistantCoordinatorApartmentprogram_9256
#   inflating: data/Resume_Files/AlbertoFlores_22007
#   inflating: data/Resume_Files/MarieJean_18645
#   inflating: data/Resume_Files/KylieWeldin_7409
#   inflating: data/Resume_Files/CraigMark_37214
#   inflating: data/Resume_Files/KarliCrigger_24236
#   inflating: data/Resume_Files/AmericanLawyerMedia_36373
#   inflating: data/Resume_Files/MichaelCothias_22737
#   inflating: data/Resume_Files/JorgeRiveraColÃ³n_18957
#   inflating: data/Resume_Files/LisaLindell_7473
#   inflating: data/Resume_Files/MERGEFORMATGlennGomez_38122
#   inflating: data/Resume_Files/CustomerServiceBillingRepresentative_35166
#   inflating: data/Resume_Files/Guard_15594
#   inflating: data/Resume_Files/ProjectArchaeologistGISAnalyst_3898
#   inflating: data/Resume_Files/JenniferJenkins_21551
#   inflating: data/Resume_Files/CUSTOMERSERVICESUPERVISOR_22413
#   inflating: data/Resume_Files/EatonLeslie_40243
#   inflating: data/Resume_Files/HavesterOperator_12686
#   inflating: data/Resume_Files/ShamikaWilliams_8249
#   inflating: data/Resume_Files/TakettaNelson_7702
#   inflating: data/Resume_Files/IzellKing_30937
#   inflating: data/Resume_Files/Bankteller_10208
#   inflating: data/Resume_Files/TeresaCompton_38613
#   inflating: data/Resume_Files/Waitress_28118
#   inflating: data/Resume_Files/QuintelHughes_26035
#   inflating: data/Resume_Files/RNAcuteCareNurse_10165
#   inflating: data/Resume_Files/InspectorPacker_39570
#   inflating: data/Resume_Files/PhysicalTherapistAssistant_39120
#   inflating: data/Resume_Files/AssemblyTechs_35214
#   inflating: data/Resume_Files/UtahDispatcher_29459
#   inflating: data/Resume_Files/HabilitationTechnician_22290
#   inflating: data/Resume_Files/JerriGrummett_21238
#   inflating: data/Resume_Files/SalesAssociateCustomerService_49842
#   inflating: data/Resume_Files/TransmissionSystemsOperator_15826
#   inflating: data/Resume_Files/ArionnaPorter_44273
#   inflating: data/Resume_Files/NeryCano_18449
#   inflating: data/Resume_Files/AdministrativeAssistantTeachersAide_3729
#   inflating: data/Resume_Files/TaiylorGreco_22668
#   inflating: data/Resume_Files/Mentalhealthprovider_22210
#   inflating: data/Resume_Files/Principleconsultant_17567
#   inflating: data/Resume_Files/ProjectEngineer_12705
#   inflating: data/Resume_Files/ValeriaCaberos_37021
#   inflating: data/tfidf_ftdmdl_resumes_21Feb21-2000
#   inflating: data/jd_id_2_filename_map.pkl
#   inflating: data/jd_big_matrix_w2v50.npy
#   inflating: data/tfidf_ftdmdl_jd_21Feb21-2056
#   inflating: data/resumes_big_matrix_w2v50.npy
#   inflating: data/glove-wiki-gigaword-50

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from pathlib import Path
import time
import pickle
base_path = Path("./data") 
choices = [base_path / "Resume_Files", base_path / "JD_Files"]
words = set()
file_number = 0
resume_file_number = len(list(choices[0].iterdir()))
jd_file_number = len(list(choices[1].iterdir()))
print(f"Job description files {jd_file_number}")
print(f"Resume file numbers, {resume_file_number}, \n \n")

for each in choices:
  for corpus_file in each.iterdir():
    tic = time.perf_counter()
    with open(corpus_file, "r", encoding="utf-8") as f:
      # Use update to automatically add iterable instead of append that adds a single element at a time
        words.update(nltk.word_tokenize(f.read()))
    toc = time.perf_counter()
    file_number += 1
    # For performance reasons only print and update pickle after every 1000 files are processed. Printing and pickling is abit slow
    if (file_number % 1000 == 0):
      print(f"Total vocabulary size at {len(words)}, File Number {file_number} \n")
      print(f"{tic-toc:0.4f} seconds")
      with open("recsys.pickle", "wb") as pf:
        pickle.dump({"file_number":file_number}, pf, protocol=pickle.HIGHEST_PROTOCOL)
        pickle.dump({"vocab":words}, pf, protocol=pickle.HIGHEST_PROTOCOL)
        pickle.dump({"vocab_length":len(words)}, pf, protocol=pickle.HIGHEST_PROTOCOL)
    

# Unpickle below
# with open("recsys.pickle","rb") as pf:
#   print(pickle.load(pf))
#   print(pickle.load(pf))
#   print(pickle.load(pf))
# Out:
# Job description files 151211
# Resume file numbers, 50032,
#
#
# Total vocabulary size at 19456, File Number 1000
#
# -0.0022 seconds
# Total vocabulary size at 27576, File Number 2000
#
# -0.0002 seconds
# Total vocabulary size at 33847, File Number 3000
#
# -0.0015 seconds
# Total vocabulary size at 39479, File Number 4000
#
# -0.0059 seconds
# Total vocabulary size at 44382, File Number 5000
#
# -0.0014 seconds
# Total vocabulary size at 48601, File Number 6000
#
# -0.0028 seconds
# Total vocabulary size at 52794, File Number 7000
#
# -0.0010 seconds
# Total vocabulary size at 56595, File Number 8000
#
# -0.0005 seconds
# Total vocabulary size at 60020, File Number 9000
#
# -0.0016 seconds
# Total vocabulary size at 63119, File Number 10000
#
# -0.0007 seconds
# Total vocabulary size at 66197, File Number 11000
#
# -0.0011 seconds
# Total vocabulary size at 69221, File Number 12000
#
# -0.0066 seconds
# Total vocabulary size at 72034, File Number 13000
#
# -0.0022 seconds
# Total vocabulary size at 74861, File Number 14000
#
# -0.0011 seconds
# Total vocabulary size at 77710, File Number 15000
#
# -0.0015 seconds
# Total vocabulary size at 80517, File Number 16000
#
# -0.0028 seconds
# Total vocabulary size at 83402, File Number 17000
#
# -0.0007 seconds
# Total vocabulary size at 86100, File Number 18000
#
# -0.0004 seconds
# Total vocabulary size at 88654, File Number 19000
#
# -0.0022 seconds
# Total vocabulary size at 91078, File Number 20000
#
# -0.0008 seconds
# Total vocabulary size at 93424, File Number 21000
#
# -0.0001 seconds
# Total vocabulary size at 95860, File Number 22000
#
# -0.0020 seconds
# Total vocabulary size at 98276, File Number 23000
#
# -0.0012 seconds
# Total vocabulary size at 100459, File Number 24000
#
# -0.0023 seconds
# Total vocabulary size at 102568, File Number 25000
#
# -0.0024 seconds
# Total vocabulary size at 104848, File Number 26000
#
# -0.0005 seconds
# Total vocabulary size at 107112, File Number 27000
#
# -0.0004 seconds
# Total vocabulary size at 109337, File Number 28000
#
# -0.0002 seconds
# Total vocabulary size at 111471, File Number 29000
#
# -0.0002 seconds
# Total vocabulary size at 113542, File Number 30000
#
# -0.0003 seconds
# Total vocabulary size at 115523, File Number 31000
#
# -0.0014 seconds
# Total vocabulary size at 117428, File Number 32000
#
# -0.0007 seconds
# Total vocabulary size at 119514, File Number 33000
#
# -0.0013 seconds
# Total vocabulary size at 121350, File Number 34000
#
# -0.0008 seconds
# Total vocabulary size at 123389, File Number 35000
#
# -0.0004 seconds
# Total vocabulary size at 125300, File Number 36000
#
# -0.0018 seconds
# Total vocabulary size at 127162, File Number 37000
#
# -0.0014 seconds
# Total vocabulary size at 129125, File Number 38000
#
# -0.0015 seconds
# Total vocabulary size at 131037, File Number 39000
#
# -0.0025 seconds
# Total vocabulary size at 132934, File Number 40000
#
# -0.0008 seconds
# Total vocabulary size at 134939, File Number 41000
#
# -0.0005 seconds
# Total vocabulary size at 136667, File Number 42000
#
# -0.0003 seconds
# Total vocabulary size at 138563, File Number 43000
#
# -0.0013 seconds
# Total vocabulary size at 140226, File Number 44000
#
# -0.0013 seconds
# Total vocabulary size at 142044, File Number 45000
#
# -0.0007 seconds
# Total vocabulary size at 143703, File Number 46000
#
# -0.0012 seconds
# Total vocabulary size at 145340, File Number 47000
#
# -0.0009 seconds
# Total vocabulary size at 147158, File Number 48000
#
# -0.0014 seconds
# Total vocabulary size at 148717, File Number 49000
#
# -0.0010 seconds
# Total vocabulary size at 150323, File Number 50000
#
# -0.0008 seconds
# Total vocabulary size at 164586, File Number 51000
#
# -0.0012 seconds
# Total vocabulary size at 175493, File Number 52000
#
# -0.0002 seconds
# Total vocabulary size at 184844, File Number 53000
#
# -0.0018 seconds
# Total vocabulary size at 193302, File Number 54000
#
# -0.0012 seconds
# Total vocabulary size at 201293, File Number 55000
#
# -0.0013 seconds
# Total vocabulary size at 209090, File Number 56000
#
# -0.0007 seconds
# Total vocabulary size at 216747, File Number 57000
#
# -0.0007 seconds
# Total vocabulary size at 224130, File Number 58000
#
# -0.0024 seconds
# Total vocabulary size at 230999, File Number 59000
#
# -0.0012 seconds
# Total vocabulary size at 237563, File Number 60000
#
# -0.0008 seconds
# Total vocabulary size at 244443, File Number 61000
#
# -0.0007 seconds
# Total vocabulary size at 250827, File Number 62000
#
# -0.0015 seconds
# Total vocabulary size at 257317, File Number 63000
#
# -0.0015 seconds
# Total vocabulary size at 264056, File Number 64000
#
# -0.0007 seconds
# Total vocabulary size at 269968, File Number 65000
#
# -0.0015 seconds
# Total vocabulary size at 275923, File Number 66000
#
# -0.0008 seconds
# Total vocabulary size at 281511, File Number 67000
#
# -0.0008 seconds
# Total vocabulary size at 287075, File Number 68000
#
# -0.0019 seconds
# Total vocabulary size at 292576, File Number 69000
#
# -0.0009 seconds
# Total vocabulary size at 298120, File Number 70000
#
# -0.0013 seconds
# Total vocabulary size at 303628, File Number 71000
#
# -0.0022 seconds
# Total vocabulary size at 309343, File Number 72000
#
# -0.0004 seconds
# Total vocabulary size at 314492, File Number 73000
#
# -0.0021 seconds
# Total vocabulary size at 319795, File Number 74000
#
# -0.0006 seconds
# Total vocabulary size at 324857, File Number 75000
#
# -0.0009 seconds
# Total vocabulary size at 329958, File Number 76000
#
# -0.0020 seconds
# Total vocabulary size at 334988, File Number 77000
#
# -0.0019 seconds
# Total vocabulary size at 340142, File Number 78000
#
# -0.0008 seconds
# Total vocabulary size at 344842, File Number 79000
#
# -0.0018 seconds
# Total vocabulary size at 349604, File Number 80000
#
# -0.0002 seconds
# Total vocabulary size at 354159, File Number 81000
#
# -0.0005 seconds
# Total vocabulary size at 359100, File Number 82000
#
# -0.0007 seconds
# Total vocabulary size at 363685, File Number 83000
#
# -0.0010 seconds
# Total vocabulary size at 368179, File Number 84000
#
# -0.0006 seconds
# Total vocabulary size at 372866, File Number 85000
#
# -0.0011 seconds
# Total vocabulary size at 377857, File Number 86000
#
# -0.0007 seconds
# Total vocabulary size at 382645, File Number 87000
#
# -0.0028 seconds
# Total vocabulary size at 387034, File Number 88000
#
# -0.0020 seconds
# Total vocabulary size at 391930, File Number 89000
#
# -0.0012 seconds
# Total vocabulary size at 396641, File Number 90000
#
# -0.0004 seconds
# Total vocabulary size at 401363, File Number 91000
#
# -0.0011 seconds
# Total vocabulary size at 405683, File Number 92000
#
# -0.0028 seconds
# Total vocabulary size at 410275, File Number 93000
#
# -0.0019 seconds
# Total vocabulary size at 414600, File Number 94000
#
# -0.0011 seconds
# Total vocabulary size at 418976, File Number 95000
#
# -0.0022 seconds
# Total vocabulary size at 423346, File Number 96000
#
# -0.0009 seconds
# Total vocabulary size at 427652, File Number 97000
#
# -0.0012 seconds
# Total vocabulary size at 431702, File Number 98000
#
# -0.0015 seconds
# Total vocabulary size at 436188, File Number 99000
#
# -0.0011 seconds
# Total vocabulary size at 440602, File Number 100000
#
# -0.0016 seconds
# Total vocabulary size at 444941, File Number 101000
#
# -0.0013 seconds
# Total vocabulary size at 448859, File Number 102000
#
# -0.0005 seconds
# Total vocabulary size at 453124, File Number 103000
#
# -0.0017 seconds
# Total vocabulary size at 457452, File Number 104000
#
# -0.0007 seconds
# Total vocabulary size at 461632, File Number 105000
#
# -0.0038 seconds
# Total vocabulary size at 465484, File Number 106000
#
# -0.0009 seconds
# Total vocabulary size at 469443, File Number 107000
#
# -0.0008 seconds
# Total vocabulary size at 473525, File Number 108000
#
# -0.0010 seconds
# Total vocabulary size at 477582, File Number 109000
#
# -0.0016 seconds
# Total vocabulary size at 481422, File Number 110000
#
# -0.0011 seconds
# Total vocabulary size at 485026, File Number 111000
#
# -0.0008 seconds
# Total vocabulary size at 489071, File Number 112000
#
# -0.0017 seconds
# Total vocabulary size at 493120, File Number 113000
#
# -0.0027 seconds
# Total vocabulary size at 496839, File Number 114000
#
# -0.0016 seconds
# Total vocabulary size at 500852, File Number 115000
#
# -0.0013 seconds
# Total vocabulary size at 504594, File Number 116000
#
# -0.0009 seconds
# Total vocabulary size at 508452, File Number 117000
#
# -0.0021 seconds
# Total vocabulary size at 512043, File Number 118000
#
# -0.0005 seconds
# Total vocabulary size at 515635, File Number 119000
#
# -0.0005 seconds
# Total vocabulary size at 519736, File Number 120000
#
# -0.0014 seconds
# Total vocabulary size at 523375, File Number 121000
#
# -0.0007 seconds
# Total vocabulary size at 527087, File Number 122000
#
# -0.0010 seconds
# Total vocabulary size at 530725, File Number 123000
#
# -0.0017 seconds
# Total vocabulary size at 534261, File Number 124000
#
# -0.0003 seconds
# Total vocabulary size at 538123, File Number 125000
#
# -0.0007 seconds
# Total vocabulary size at 542015, File Number 126000
#
# -0.0012 seconds
# Total vocabulary size at 545579, File Number 127000
#
# -0.0004 seconds
# Total vocabulary size at 549191, File Number 128000
#
# -0.0003 seconds
# Total vocabulary size at 552712, File Number 129000
#
# -0.0011 seconds
# Total vocabulary size at 556374, File Number 130000
#
# -0.0028 seconds
# Total vocabulary size at 559990, File Number 131000
#
# -0.0032 seconds
# Total vocabulary size at 563691, File Number 132000
#
# -0.0006 seconds
# Total vocabulary size at 567528, File Number 133000
#
# -0.0008 seconds
# Total vocabulary size at 571119, File Number 134000
#
# -0.0003 seconds
# Total vocabulary size at 574647, File Number 135000
#
# -0.0006 seconds
# Total vocabulary size at 578201, File Number 136000
#
# -0.0017 seconds
# Total vocabulary size at 581575, File Number 137000
#
# -0.0009 seconds
# Total vocabulary size at 585374, File Number 138000
#
# -0.0015 seconds
# Total vocabulary size at 588971, File Number 139000
#
# -0.0015 seconds
# Total vocabulary size at 592351, File Number 140000
#
# -0.0009 seconds
# Total vocabulary size at 595816, File Number 141000
#
# -0.0014 seconds
# Total vocabulary size at 599314, File Number 142000
#
# -0.0017 seconds
# Total vocabulary size at 602722, File Number 143000
#
# -0.0021 seconds
# Total vocabulary size at 606225, File Number 144000
#
# -0.0008 seconds
# Total vocabulary size at 609852, File Number 145000
#
# -0.0010 seconds
# Total vocabulary size at 613012, File Number 146000
#
# -0.0006 seconds
# Total vocabulary size at 616307, File Number 147000
#
# -0.0002 seconds
# Total vocabulary size at 619506, File Number 148000
#
# -0.0003 seconds
# Total vocabulary size at 622577, File Number 149000
#
# -0.0007 seconds
# Total vocabulary size at 625857, File Number 150000
#
# -0.0003 seconds
# Total vocabulary size at 629319, File Number 151000
#
# -0.0009 seconds
# Total vocabulary size at 632601, File Number 152000
#
# -0.0017 seconds
# Total vocabulary size at 635933, File Number 153000
#
# -0.0014 seconds
# Total vocabulary size at 639138, File Number 154000
#
# -0.0011 seconds
# Total vocabulary size at 642354, File Number 155000
#
# -0.0017 seconds
# Total vocabulary size at 645666, File Number 156000
#
# -0.0013 seconds
# Total vocabulary size at 649142, File Number 157000
#
# -0.0025 seconds
# Total vocabulary size at 652144, File Number 158000
#
# -0.0005 seconds
# Total vocabulary size at 655286, File Number 159000
#
# -0.0010 seconds
# Total vocabulary size at 658484, File Number 160000
#
# -0.0012 seconds
# Total vocabulary size at 661847, File Number 161000
#
# -0.0019 seconds
# Total vocabulary size at 665078, File Number 162000
#
# -0.0013 seconds
# Total vocabulary size at 668188, File Number 163000
#
# -0.0008 seconds
# Total vocabulary size at 671361, File Number 164000
#
# -0.0015 seconds
# Total vocabulary size at 674508, File Number 165000
#
# -0.0015 seconds
# Total vocabulary size at 677563, File Number 166000
#
# -0.0010 seconds
# Total vocabulary size at 680672, File Number 167000
#
# -0.0021 seconds
# Total vocabulary size at 683656, File Number 168000
#
# -0.0005 seconds
# Total vocabulary size at 686768, File Number 169000
#
# -0.0008 seconds
# Total vocabulary size at 689623, File Number 170000
#
# -0.0012 seconds
# Total vocabulary size at 692456, File Number 171000
#
# -0.0033 seconds
# Total vocabulary size at 695502, File Number 172000
#
# -0.0007 seconds
# Total vocabulary size at 698741, File Number 173000
#
# -0.0015 seconds
# Total vocabulary size at 701810, File Number 174000
#
# -0.0010 seconds
# Total vocabulary size at 704720, File Number 175000
#
# -0.0016 seconds
# Total vocabulary size at 707821, File Number 176000
#
# -0.0023 seconds
# Total vocabulary size at 710552, File Number 177000
#
# -0.0003 seconds
# Total vocabulary size at 713613, File Number 178000
#
# -0.0008 seconds
# Total vocabulary size at 716895, File Number 179000
#
# -0.0009 seconds
# Total vocabulary size at 719898, File Number 180000
#
# -0.0008 seconds
# Total vocabulary size at 722767, File Number 181000
#
# -0.0015 seconds
# Total vocabulary size at 726105, File Number 182000
#
# -0.0008 seconds
# Total vocabulary size at 729120, File Number 183000
#
# -0.0021 seconds
# Total vocabulary size at 732089, File Number 184000
#
# -0.0008 seconds
# Total vocabulary size at 735156, File Number 185000
#
# -0.0009 seconds
# Total vocabulary size at 738177, File Number 186000
#
# -0.0015 seconds
# Total vocabulary size at 741278, File Number 187000
#
# -0.0015 seconds
# Total vocabulary size at 744337, File Number 188000
#
# -0.0018 seconds
# Total vocabulary size at 747549, File Number 189000
#
# -0.0011 seconds
# Total vocabulary size at 750307, File Number 190000
#
# -0.0020 seconds
# Total vocabulary size at 753145, File Number 191000
#
# -0.0009 seconds
# Total vocabulary size at 755988, File Number 192000
#
# -0.0009 seconds
# Total vocabulary size at 759138, File Number 193000
#
# -0.0019 seconds
# Total vocabulary size at 762067, File Number 194000
#
# -0.0018 seconds
# Total vocabulary size at 764821, File Number 195000
#
# -0.0043 seconds
# Total vocabulary size at 767577, File Number 196000
#
# -0.0035 seconds
# Total vocabulary size at 770548, File Number 197000
#
# -0.0009 seconds
# Total vocabulary size at 773455, File Number 198000
#
# -0.0021 seconds
# Total vocabulary size at 776438, File Number 199000
#
# -0.0024 seconds
# Total vocabulary size at 779286, File Number 200000
#
# -0.0006 seconds
# Total vocabulary size at 782267, File Number 201000
#
# -0.0013 seconds
